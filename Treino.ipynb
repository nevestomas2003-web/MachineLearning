# %% [markdown]
# <a href="https://colab.research.google.com/github/nevestomas2003-web/MachineLearning/blob/main/Treino.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s="firstString"

print(s[-1:6])

# %%
colors=["red", "blue", 4 , "black", 5]
print(colors[1:4])
print(colors[:3])

colors.append("black")
print(colors)

colors.pop()
print(colors)
colors.pop(1)
print(colors)
# Out:
# ['blue', 4, 'black']
# ['red', 'blue', 4]
# ['red', 'blue', 4, 'black', 5, 'black']
# ['red', 'blue', 4, 'black', 5]
# ['red', 4, 'black', 5]

# %%
colors=["red", "blue", 4 , "black", 5]
colors_light=["lighred, lightblue"]

colors=2 * colors_light
print(colors)
# Out:
# ['lighred, lightblue', 'lighred, lightblue']

# %%
tel={"Mary":935363478, "John":961547986}
print(tel.keys())
# Out:
# dict_keys(['Mary', 'John'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
